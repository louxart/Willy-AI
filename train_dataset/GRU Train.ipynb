# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df =pd.read_csv("ventas_detalladas_2025_v3_1.csv")
df.head()
# Out:
#    Num_Boleta       Fecha       SKU                 Descripcion  Categoria  \
# 0  B25-000001  2025-01-01  SKU-0909  Ron Santiago Queirolo 200g    Licores
# 1  B25-000001  2025-01-01  SKU-0497         Avena Inca Sur 500g  Abarrotes
# 2  B25-000002  2025-01-01  SKU-0986       Panetón Gloria unidad  Panadería
# 3  B25-000002  2025-01-01  SKU-0741        Gaseosa Coca Cola 1L    Bebidas
# 4  B25-000002  2025-01-01  SKU-0354      Mantequilla Vigor 400g    Lácteos
#
#   Unidad_medida  Precio_unidad  Cantidad_item  Subtotal_item  \
# 0          unit           39.0              2           78.0
# 1          unit           11.8              2           23.6
# 2          unit           19.3              1           19.3
# 3          unit           12.0              1           12.0
# 4          unit            9.0              1            9.0
#
#    Importe_total_boleta
# 0                 101.6
# 1                 101.6
# 2                  40.3
# 3                  40.3
# 4                  40.3

# %%
fe = pd.read_csv("feriados_peru_2025.csv")
fe.head()
# Out:
#         Fecha Día_semana                            Festividad
# 0  2025-01-01  Miércoles                             Año Nuevo
# 1  2025-04-17     Jueves                          Jueves Santo
# 2  2025-04-18    Viernes                         Viernes Santo
# 3  2025-05-01     Jueves                       Día del Trabajo
# 4  2025-06-07     Sábado  Batalla de Arica y Día de la Bandera

# %%
pr = pd.read_csv("productos_2025.csv")
pr.head()
# Out:
#         SKU               Descripcion  Categoria Unidad_medida  Precio_base  \
# 0  SKU-0001       Huevo a granel (kg)  Abarrotes            kg         10.0
# 1  SKU-0002         Arroz Faraón (kg)  Abarrotes            kg          4.4
# 2  SKU-0003         Azúcar rubia (kg)  Abarrotes            kg          3.8
# 3  SKU-0004             Lentejas (kg)  Abarrotes            kg          7.0
# 4  SKU-0005  Atún Florida Trozos 170g  Conservas          unit          5.0
#
#   Rotacion
# 0     alta
# 1     alta
# 2     alta
# 3    media
# 4    media

# %% [markdown]
# ### INGENIERIA DE CARACTERISTICAS

# %% [markdown]
# productos_2025

# %%
rotacion_map = {'alta': 3, 'media': 2, 'baja': 1}
pr['Rotacion_Cod'] = pr['Rotacion'].map(rotacion_map)

pr_features = pr[['SKU', 'Precio_base', 'Rotacion_Cod']]

# %% [markdown]
# feriados

# %%
fe['Fecha'] = pd.to_datetime(fe['Fecha'])

feriados_set = set(fe['Fecha'])

# %% [markdown]
# ventas_detalladas

# %%
df['Fecha'] = pd.to_datetime(df['Fecha'])

# %%
df['Es_Feriado'] = df['Fecha'].isin(feriados_set).astype(int)
df.set_index('Fecha', inplace=True)

print("Agrupando 50,000 transacciones por SKU y Quincena (2W)...")
df_agregado = df.groupby('SKU').resample('2W').agg(
    
    Demanda_Total=('Cantidad_item', 'sum'),
    
    Precio_Prom_Venta=('Precio_unidad', 'mean'),
    
    Num_Transacciones=('Num_Boleta', 'nunique'),
    
    Num_Feriados=('Es_Feriado', 'sum')
).fillna(0) 

df_agregado.reset_index(inplace=True)
# Out:
# Agrupando 50,000 transacciones por SKU y Quincena (2W)...
# C:\Users\agabr\AppData\Local\Temp\ipykernel_11468\2568005.py:10: FutureWarning: DataFrameGroupBy.resample operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_agregado = df.groupby('SKU').resample('2W').agg(

# %%
print("Uniendo datos quincenales con datos de productos...")
df_enriquecido = pd.merge(
    df_agregado, 
    pr_features, 
    on='SKU', 
    how='left' 
)
# Out:
# Uniendo datos quincenales con datos de productos...

# %%
print("Creando la variable Target (Demanda Futura)...")

df_enriquecido['Target_Demanda_Futura'] = df_enriquecido.groupby('SKU')['Demanda_Total'].shift(-1)

df_enriquecido.fillna(0, inplace=True) 

df_final = df_enriquecido.dropna(subset=['Target_Demanda_Futura'])
# Out:
# Creando la variable Target (Demanda Futura)...

# %%
print("\n--- ¡Ingeniería de Características Completada! ---")
print("DataFrame final listo para secuenciar:")
print(df_final.head())
print("\nInformación del DataFrame final:")
df_final.info()
# Out:
# --- ¡Ingeniería de Características Completada! ---
# DataFrame final listo para secuenciar:
#         SKU      Fecha  Demanda_Total  Precio_Prom_Venta  Num_Transacciones  \
# 0  SKU-0001 2025-01-05             48           9.962500                 16
# 1  SKU-0001 2025-01-19            109           9.852632                 38
# 2  SKU-0001 2025-02-02            131           9.649057                 53
# 3  SKU-0001 2025-02-16            102           9.454054                 37
# 4  SKU-0001 2025-03-02            126           9.289583                 48
#
#    Num_Feriados  Precio_base  Rotacion_Cod  Target_Demanda_Futura
# 0             1         10.0             3                  109.0
# 1             0         10.0             3                  131.0
# 2             0         10.0             3                  102.0
# 3             0         10.0             3                  126.0
# 4             0         10.0             3                  115.0
#
# Información del DataFrame final:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25013 entries, 0 to 25012
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   SKU                    25013 non-null  object
#  1   Fecha                  25013 non-null  datetime64[ns]
#  2   Demanda_Total          25013 non-null  int64
#  3   Precio_Prom_Venta      25013 non-null  float64
#  4   Num_Transacciones      25013 non-null  int64
#  5   Num_Feriados           25013 non-null  int64
#  6   Precio_base            25013 non-null  float64
#  7   Rotacion_Cod           25013 non-null  int64
#  8   Target_Demanda_Futura  25013 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(4), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
FEATURES = ['Demanda_Total', 'Precio_Prom_Venta', 'Num_Transacciones', 
            'Num_Feriados', 'Precio_base', 'Rotacion_Cod']
TARGET = 'Target_Demanda_Futura'

scaler_x = MinMaxScaler(feature_range=(0, 1))
scaler_y = MinMaxScaler(feature_range=(0, 1))

df_scaled = df_final.copy()

df_scaled[FEATURES] = scaler_x.fit_transform(df_final[FEATURES])

df_scaled[TARGET] = scaler_y.fit_transform(df_final[[TARGET]])

print("Datos escalados (normalizados entre 0 y 1).")
# Out:
# Datos escalados (normalizados entre 0 y 1).

# %%
#print("Creando secuencias 3D (ventanas de tiempo)...")

# Usaremos 5 quincenas pasadas para predecir la 6ta.
TIME_STEPS = 5 

def create_sequences(data, features, target, time_steps):
    X_seq, Y_seq = [], []
    
   
    for sku, group in data.groupby('SKU'):
        
        feature_data = group[features].values
        target_data = group[target].values
        
       
        for i in range(len(group) - time_steps):
            
            X_sample = feature_data[i : (i + time_steps)]
           
            Y_sample = target_data[i + time_steps]
            
            X_seq.append(X_sample)
            Y_seq.append(Y_sample)
            
    return np.array(X_seq), np.array(Y_seq)

X, Y = create_sequences(df_scaled, FEATURES, TARGET, TIME_STEPS)

print(f"Secuenciación completa. Se crearon {len(X)} muestras.")
# Out:
# Creando secuencias 3D (ventanas de tiempo)...
# Secuenciación completa. Se crearon 20105 muestras.

# %%
#print("Dividiendo en sets de Entrenamiento, Validación y Prueba...")

total_samples = len(X)
train_size = int(total_samples * 0.70)
val_size = int(total_samples * 0.15)
# El resto es 'test_size'

# División secuencial
X_train, Y_train = X[0:train_size], Y[0:train_size]
X_val, Y_val = X[train_size : train_size + val_size], Y[train_size : train_size + val_size]
X_test, Y_test = X[train_size + val_size :], Y[train_size + val_size :]

print("\n--- ¡Preparación de Datos Completada! ---")
print("Formatos (shapes) de los datos listos para el GRU:")
print(f"X_train (Muestras, Pasos_Tiempo, Features): {X_train.shape}")
print(f"Y_train (Muestras):                       {Y_train.shape}")
print(f"X_val:                                    {X_val.shape}")
print(f"Y_val:                                    {Y_val.shape}")
print(f"X_test:                                   {X_test.shape}")
print(f"Y_test:                                   {Y_test.shape}")

print("\nScalers 'scaler_x' y 'scaler_y' están listos en memoria.")
# Out:
# Dividiendo en sets de Entrenamiento, Validación y Prueba...
#
# --- ¡Preparación de Datos Completada! ---
# Formatos (shapes) de los datos listos para el GRU:
# X_train (Muestras, Pasos_Tiempo, Features): (14073, 5, 6)
# Y_train (Muestras):                       (14073,)
# X_val:                                    (3015, 5, 6)
# Y_val:                                    (3015,)
# X_test:                                   (3017, 5, 6)
# Y_test:                                   (3017,)
#
# Scalers 'scaler_x' y 'scaler_y' están listos en memoria.

# %% [markdown]
# ### TRAIN

# %%
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

# %%
X_train_tensor = torch.tensor(X_train).float()
Y_train_tensor = torch.tensor(Y_train).float()

X_val_tensor = torch.tensor(X_val).float()
Y_val_tensor = torch.tensor(Y_val).float()

X_test_tensor = torch.tensor(X_test).float()
Y_test_tensor = torch.tensor(Y_test).float()

# %%
Y_train_tensor = Y_train_tensor.unsqueeze(1)
Y_val_tensor = Y_val_tensor.unsqueeze(1)
Y_test_tensor = Y_test_tensor.unsqueeze(1)

# %%
batch_size = 64

# %%
train_dataset = TensorDataset(X_train_tensor, Y_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

val_dataset = TensorDataset(X_val_tensor, Y_val_tensor)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

test_dataset = TensorDataset(X_test_tensor, Y_test_tensor)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f"DataLoaders listos. Tamaño del lote (batch_size): {batch_size}")
# Out:
# DataLoaders listos. Tamaño del lote (batch_size): 64

# %% [markdown]
# GRU

# %%
from sklearn.metrics import r2_score
import copy

# %%
class GRUModel(nn.Module):
    
    # Añadimos 'dropout_prob'
    def __init__(self, input_size, hidden_size, num_layers, output_size, dropout_prob):
        super(GRUModel, self).__init__()
        
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        
        self.gru = nn.GRU(input_size, 
                          hidden_size, 
                          num_layers, 
                          batch_first=True,
                          dropout=dropout_prob)
        
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size)
        out, _ = self.gru(x, h0)
        out = self.fc(out[:, -1, :])
        return out

# %% [markdown]
# TRAIN

# %%
#Hiperparametros
INPUT_SIZE = X_train_tensor.shape[2] 
OUTPUT_SIZE = 1 
HIDDEN_SIZE = 128
NUM_LAYERS = 3
LEARNING_RATE = 0.0002
NUM_EPOCHS = 500 
CLIP_VALUE = 1.0 # (Para Gradient Clipping)
DROPOUT_PROB = 0.5 # (50% de apagado aleatorio)
PATIENCE = 20 

model = GRUModel(INPUT_SIZE, HIDDEN_SIZE, NUM_LAYERS, OUTPUT_SIZE, DROPOUT_PROB)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

print(f"Iniciando entrenamiento con {NUM_EPOCHS} épocas (Paciencia={PATIENCE})...")

history_loss = []
history_val_loss = []
history_r2_score = [] 

best_val_loss = float('inf') 
patience_counter = 0
best_model_weights = None 

for epoch in range(NUM_EPOCHS):
    
    # --- Entrenamiento ---
    model.train()
    epoch_train_loss = 0.0
    for batch_X, batch_Y in train_loader:
        outputs = model(batch_X)
        loss = criterion(outputs, batch_Y)
        optimizer.zero_grad()
        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), CLIP_VALUE)

        optimizer.step()
        epoch_train_loss += loss.item()
        
    avg_train_loss = epoch_train_loss / len(train_loader)
    history_loss.append(avg_train_loss)

    model.eval()
    epoch_val_loss = 0.0

    all_y_val = []
    all_outputs_val = []
    
    with torch.no_grad():
        for batch_X_val, batch_Y_val in val_loader:
            outputs_val = model(batch_X_val)
            loss_val = criterion(outputs_val, batch_Y_val)
            epoch_val_loss += loss_val.item()
            
            # Guardamos los tensores (en CPU) para el R²
            all_y_val.append(batch_Y_val.cpu())
            all_outputs_val.append(outputs_val.cpu())
            
    avg_val_loss = epoch_val_loss / len(val_loader)
    history_val_loss.append(avg_val_loss)
    
    # Concatenamos todos los lotes de validación
    all_y_val = torch.cat(all_y_val).numpy()
    all_outputs_val = torch.cat(all_outputs_val).numpy()
    
    # Calculamos R²
    r2 = r2_score(all_y_val, all_outputs_val)
    history_r2_score.append(r2)
    
    # Imprimir el progreso
    print(f"Epoch [{epoch+1}/{NUM_EPOCHS}], Loss(Train): {avg_train_loss:.5f}, Loss(Val): {avg_val_loss:.5f}, R² (Val): {r2:.4f}")


    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        patience_counter = 0 
        best_model_weights = copy.deepcopy(model.state_dict())
        print(f"   -> Mejorado. Guardando modelo...")
    else:
        patience_counter += 1
        
    if patience_counter >= PATIENCE:
        print(f"\n¡Early Stopping activado en la época {epoch+1}!")
        print(f"La pérdida de validación no mejoró por {PATIENCE} épocas.")
        break 

if best_model_weights:
    print("Cargando pesos del mejor modelo guardado.")
    model.load_state_dict(best_model_weights)

print("Entrenamiento completado.")
# Out:
# Iniciando entrenamiento con 500 épocas (Paciencia=20)...
# Epoch [1/500], Loss(Train): 0.00143, Loss(Val): 0.00042, R² (Val): -0.0086
#    -> Mejorado. Guardando modelo...
# Epoch [2/500], Loss(Train): 0.00063, Loss(Val): 0.00038, R² (Val): 0.0892
#    -> Mejorado. Guardando modelo...
# Epoch [3/500], Loss(Train): 0.00060, Loss(Val): 0.00041, R² (Val): 0.0131
# Epoch [4/500], Loss(Train): 0.00060, Loss(Val): 0.00041, R² (Val): 0.0231
# Epoch [5/500], Loss(Train): 0.00054, Loss(Val): 0.00038, R² (Val): 0.0747
# Epoch [6/500], Loss(Train): 0.00055, Loss(Val): 0.00039, R² (Val): 0.0566
# Epoch [7/500], Loss(Train): 0.00055, Loss(Val): 0.00039, R² (Val): 0.0743
# Epoch [8/500], Loss(Train): 0.00056, Loss(Val): 0.00037, R² (Val): 0.1029
#    -> Mejorado. Guardando modelo...
# Epoch [9/500], Loss(Train): 0.00054, Loss(Val): 0.00039, R² (Val): 0.0731
# Epoch [10/500], Loss(Train): 0.00054, Loss(Val): 0.00037, R² (Val): 0.1095
#    -> Mejorado. Guardando modelo...
# Epoch [11/500], Loss(Train): 0.00053, Loss(Val): 0.00039, R² (Val): 0.0611
# Epoch [12/500], Loss(Train): 0.00058, Loss(Val): 0.00038, R² (Val): 0.0841
# Epoch [13/500], Loss(Train): 0.00055, Loss(Val): 0.00044, R² (Val): -0.0519
# Epoch [14/500], Loss(Train): 0.00053, Loss(Val): 0.00039, R² (Val): 0.0618
# Epoch [15/500], Loss(Train): 0.00053, Loss(Val): 0.00038, R² (Val): 0.0794
# Epoch [16/500], Loss(Train): 0.00051, Loss(Val): 0.00038, R² (Val): 0.0920
# Epoch [17/500], Loss(Train): 0.00054, Loss(Val): 0.00037, R² (Val): 0.1055
# Epoch [18/500], Loss(Train): 0.00053, Loss(Val): 0.00038, R² (Val): 0.0887
# Epoch [19/500], Loss(Train): 0.00052, Loss(Val): 0.00039, R² (Val): 0.0598
# Epoch [20/500], Loss(Train): 0.00053, Loss(Val): 0.00037, R² (Val): 0.1103
#    -> Mejorado. Guardando modelo...
# Epoch [21/500], Loss(Train): 0.00054, Loss(Val): 0.00040, R² (Val): 0.0426
# Epoch [22/500], Loss(Train): 0.00050, Loss(Val): 0.00038, R² (Val): 0.0882
# Epoch [23/500], Loss(Train): 0.00053, Loss(Val): 0.00037, R² (Val): 0.1036
# Epoch [24/500], Loss(Train): 0.00051, Loss(Val): 0.00038, R² (Val): 0.0761
# Epoch [25/500], Loss(Train): 0.00048, Loss(Val): 0.00037, R² (Val): 0.1000
# Epoch [26/500], Loss(Train): 0.00053, Loss(Val): 0.00039, R² (Val): 0.0745
# Epoch [27/500], Loss(Train): 0.00051, Loss(Val): 0.00040, R² (Val): 0.0314
# Epoch [28/500], Loss(Train): 0.00053, Loss(Val): 0.00039, R² (Val): 0.0540
# Epoch [29/500], Loss(Train): 0.00051, Loss(Val): 0.00037, R² (Val): 0.1008
# Epoch [30/500], Loss(Train): 0.00053, Loss(Val): 0.00037, R² (Val): 0.1104
#    -> Mejorado. Guardando modelo...
# Epoch [31/500], Loss(Train): 0.00051, Loss(Val): 0.00039, R² (Val): 0.0747
# Epoch [32/500], Loss(Train): 0.00047, Loss(Val): 0.00041, R² (Val): 0.0208
# Epoch [33/500], Loss(Train): 0.00051, Loss(Val): 0.00039, R² (Val): 0.0657
# Epoch [34/500], Loss(Train): 0.00049, Loss(Val): 0.00038, R² (Val): 0.0887
# Epoch [35/500], Loss(Train): 0.00051, Loss(Val): 0.00037, R² (Val): 0.1102
#    -> Mejorado. Guardando modelo...
# Epoch [36/500], Loss(Train): 0.00050, Loss(Val): 0.00038, R² (Val): 0.0819
# Epoch [37/500], Loss(Train): 0.00048, Loss(Val): 0.00039, R² (Val): 0.0533
# Epoch [38/500], Loss(Train): 0.00051, Loss(Val): 0.00037, R² (Val): 0.1036
# Epoch [39/500], Loss(Train): 0.00050, Loss(Val): 0.00039, R² (Val): 0.0677
# Epoch [40/500], Loss(Train): 0.00050, Loss(Val): 0.00037, R² (Val): 0.1037
# Epoch [41/500], Loss(Train): 0.00047, Loss(Val): 0.00039, R² (Val): 0.0550
# Epoch [42/500], Loss(Train): 0.00053, Loss(Val): 0.00037, R² (Val): 0.1165
#    -> Mejorado. Guardando modelo...
# Epoch [43/500], Loss(Train): 0.00051, Loss(Val): 0.00037, R² (Val): 0.1122
# Epoch [44/500], Loss(Train): 0.00049, Loss(Val): 0.00037, R² (Val): 0.1094
# Epoch [45/500], Loss(Train): 0.00049, Loss(Val): 0.00037, R² (Val): 0.0992
# Epoch [46/500], Loss(Train): 0.00047, Loss(Val): 0.00037, R² (Val): 0.1028
# Epoch [47/500], Loss(Train): 0.00049, Loss(Val): 0.00037, R² (Val): 0.1063
# Epoch [48/500], Loss(Train): 0.00049, Loss(Val): 0.00037, R² (Val): 0.1096
# Epoch [49/500], Loss(Train): 0.00048, Loss(Val): 0.00037, R² (Val): 0.1105
# Epoch [50/500], Loss(Train): 0.00049, Loss(Val): 0.00038, R² (Val): 0.0868
# Epoch [51/500], Loss(Train): 0.00048, Loss(Val): 0.00037, R² (Val): 0.1180
#    -> Mejorado. Guardando modelo...
# Epoch [52/500], Loss(Train): 0.00050, Loss(Val): 0.00039, R² (Val): 0.0535
# Epoch [53/500], Loss(Train): 0.00048, Loss(Val): 0.00037, R² (Val): 0.1067
# Epoch [54/500], Loss(Train): 0.00050, Loss(Val): 0.00037, R² (Val): 0.1019
# Epoch [55/500], Loss(Train): 0.00048, Loss(Val): 0.00038, R² (Val): 0.0921
# Epoch [56/500], Loss(Train): 0.00049, Loss(Val): 0.00037, R² (Val): 0.1013
# Epoch [57/500], Loss(Train): 0.00048, Loss(Val): 0.00037, R² (Val): 0.1207
#    -> Mejorado. Guardando modelo...
# Epoch [58/500], Loss(Train): 0.00047, Loss(Val): 0.00037, R² (Val): 0.1133
# Epoch [59/500], Loss(Train): 0.00046, Loss(Val): 0.00037, R² (Val): 0.1182
# Epoch [60/500], Loss(Train): 0.00046, Loss(Val): 0.00037, R² (Val): 0.1137
# Epoch [61/500], Loss(Train): 0.00047, Loss(Val): 0.00037, R² (Val): 0.1144
# Epoch [62/500], Loss(Train): 0.00049, Loss(Val): 0.00037, R² (Val): 0.1018
# Epoch [63/500], Loss(Train): 0.00048, Loss(Val): 0.00037, R² (Val): 0.1187
# Epoch [64/500], Loss(Train): 0.00049, Loss(Val): 0.00037, R² (Val): 0.1181
# Epoch [65/500], Loss(Train): 0.00050, Loss(Val): 0.00037, R² (Val): 0.1198
# Epoch [66/500], Loss(Train): 0.00050, Loss(Val): 0.00037, R² (Val): 0.1162
# Epoch [67/500], Loss(Train): 0.00047, Loss(Val): 0.00037, R² (Val): 0.1039
# Epoch [68/500], Loss(Train): 0.00047, Loss(Val): 0.00037, R² (Val): 0.1132
# Epoch [69/500], Loss(Train): 0.00048, Loss(Val): 0.00037, R² (Val): 0.1144
# Epoch [70/500], Loss(Train): 0.00047, Loss(Val): 0.00038, R² (Val): 0.0914
# Epoch [71/500], Loss(Train): 0.00047, Loss(Val): 0.00037, R² (Val): 0.1212
#    -> Mejorado. Guardando modelo...
# Epoch [72/500], Loss(Train): 0.00048, Loss(Val): 0.00038, R² (Val): 0.0849
# Epoch [73/500], Loss(Train): 0.00049, Loss(Val): 0.00037, R² (Val): 0.1115
# Epoch [74/500], Loss(Train): 0.00047, Loss(Val): 0.00037, R² (Val): 0.1166
# Epoch [75/500], Loss(Train): 0.00048, Loss(Val): 0.00040, R² (Val): 0.0488
# Epoch [76/500], Loss(Train): 0.00048, Loss(Val): 0.00037, R² (Val): 0.1094
# Epoch [77/500], Loss(Train): 0.00051, Loss(Val): 0.00038, R² (Val): 0.0779
# Epoch [78/500], Loss(Train): 0.00048, Loss(Val): 0.00037, R² (Val): 0.1170
# Epoch [79/500], Loss(Train): 0.00047, Loss(Val): 0.00038, R² (Val): 0.0878
# Epoch [80/500], Loss(Train): 0.00048, Loss(Val): 0.00039, R² (Val): 0.0651
# Epoch [81/500], Loss(Train): 0.00048, Loss(Val): 0.00037, R² (Val): 0.1164
# Epoch [82/500], Loss(Train): 0.00048, Loss(Val): 0.00040, R² (Val): 0.0408
# Epoch [83/500], Loss(Train): 0.00048, Loss(Val): 0.00037, R² (Val): 0.1164
# Epoch [84/500], Loss(Train): 0.00049, Loss(Val): 0.00038, R² (Val): 0.0918
# Epoch [85/500], Loss(Train): 0.00048, Loss(Val): 0.00038, R² (Val): 0.0814
# Epoch [86/500], Loss(Train): 0.00049, Loss(Val): 0.00037, R² (Val): 0.1068
# Epoch [87/500], Loss(Train): 0.00047, Loss(Val): 0.00037, R² (Val): 0.1087
# Epoch [88/500], Loss(Train): 0.00048, Loss(Val): 0.00038, R² (Val): 0.0958
# Epoch [89/500], Loss(Train): 0.00048, Loss(Val): 0.00037, R² (Val): 0.1149
# Epoch [90/500], Loss(Train): 0.00047, Loss(Val): 0.00036, R² (Val): 0.1235
#    -> Mejorado. Guardando modelo...
# Epoch [91/500], Loss(Train): 0.00050, Loss(Val): 0.00037, R² (Val): 0.1147
# Epoch [92/500], Loss(Train): 0.00047, Loss(Val): 0.00036, R² (Val): 0.1236
#    -> Mejorado. Guardando modelo...
# Epoch [93/500], Loss(Train): 0.00048, Loss(Val): 0.00037, R² (Val): 0.1145
# Epoch [94/500], Loss(Train): 0.00049, Loss(Val): 0.00037, R² (Val): 0.1178
# Epoch [95/500], Loss(Train): 0.00048, Loss(Val): 0.00036, R² (Val): 0.1246
#    -> Mejorado. Guardando modelo...
# Epoch [96/500], Loss(Train): 0.00048, Loss(Val): 0.00037, R² (Val): 0.1221
# Epoch [97/500], Loss(Train): 0.00048, Loss(Val): 0.00037, R² (Val): 0.1192
# Epoch [98/500], Loss(Train): 0.00048, Loss(Val): 0.00037, R² (Val): 0.1183
# Epoch [99/500], Loss(Train): 0.00046, Loss(Val): 0.00037, R² (Val): 0.1150
# Epoch [100/500], Loss(Train): 0.00046, Loss(Val): 0.00037, R² (Val): 0.1135
# Epoch [101/500], Loss(Train): 0.00047, Loss(Val): 0.00036, R² (Val): 0.1242
# Epoch [102/500], Loss(Train): 0.00048, Loss(Val): 0.00036, R² (Val): 0.1244
# Epoch [103/500], Loss(Train): 0.00047, Loss(Val): 0.00037, R² (Val): 0.1139
# Epoch [104/500], Loss(Train): 0.00046, Loss(Val): 0.00037, R² (Val): 0.1062
# Epoch [105/500], Loss(Train): 0.00048, Loss(Val): 0.00037, R² (Val): 0.1143
# Epoch [106/500], Loss(Train): 0.00048, Loss(Val): 0.00037, R² (Val): 0.1167
# Epoch [107/500], Loss(Train): 0.00046, Loss(Val): 0.00038, R² (Val): 0.0913
# Epoch [108/500], Loss(Train): 0.00047, Loss(Val): 0.00037, R² (Val): 0.1210
# Epoch [109/500], Loss(Train): 0.00047, Loss(Val): 0.00039, R² (Val): 0.0553
# Epoch [110/500], Loss(Train): 0.00047, Loss(Val): 0.00037, R² (Val): 0.1147
# Epoch [111/500], Loss(Train): 0.00047, Loss(Val): 0.00037, R² (Val): 0.1207
# Epoch [112/500], Loss(Train): 0.00048, Loss(Val): 0.00036, R² (Val): 0.1246
# Epoch [113/500], Loss(Train): 0.00046, Loss(Val): 0.00037, R² (Val): 0.1209
# Epoch [114/500], Loss(Train): 0.00048, Loss(Val): 0.00036, R² (Val): 0.1257
#    -> Mejorado. Guardando modelo...
# Epoch [115/500], Loss(Train): 0.00049, Loss(Val): 0.00037, R² (Val): 0.1188
# Epoch [116/500], Loss(Train): 0.00046, Loss(Val): 0.00036, R² (Val): 0.1256
#    -> Mejorado. Guardando modelo...
# Epoch [117/500], Loss(Train): 0.00046, Loss(Val): 0.00037, R² (Val): 0.1160
# Epoch [118/500], Loss(Train): 0.00049, Loss(Val): 0.00037, R² (Val): 0.1220
# Epoch [119/500], Loss(Train): 0.00047, Loss(Val): 0.00037, R² (Val): 0.1093
# Epoch [120/500], Loss(Train): 0.00047, Loss(Val): 0.00037, R² (Val): 0.1062
# Epoch [121/500], Loss(Train): 0.00048, Loss(Val): 0.00037, R² (Val): 0.1180
# Epoch [122/500], Loss(Train): 0.00047, Loss(Val): 0.00036, R² (Val): 0.1245
# Epoch [123/500], Loss(Train): 0.00046, Loss(Val): 0.00037, R² (Val): 0.1128
# Epoch [124/500], Loss(Train): 0.00047, Loss(Val): 0.00037, R² (Val): 0.1185
# Epoch [125/500], Loss(Train): 0.00047, Loss(Val): 0.00036, R² (Val): 0.1236
# Epoch [126/500], Loss(Train): 0.00048, Loss(Val): 0.00036, R² (Val): 0.1233
# Epoch [127/500], Loss(Train): 0.00047, Loss(Val): 0.00037, R² (Val): 0.1196
# Epoch [128/500], Loss(Train): 0.00046, Loss(Val): 0.00036, R² (Val): 0.1269
#    -> Mejorado. Guardando modelo...
# Epoch [129/500], Loss(Train): 0.00047, Loss(Val): 0.00036, R² (Val): 0.1255
# Epoch [130/500], Loss(Train): 0.00047, Loss(Val): 0.00037, R² (Val): 0.1225
# Epoch [131/500], Loss(Train): 0.00045, Loss(Val): 0.00037, R² (Val): 0.1198
# Epoch [132/500], Loss(Train): 0.00048, Loss(Val): 0.00037, R² (Val): 0.1061
# Epoch [133/500], Loss(Train): 0.00047, Loss(Val): 0.00037, R² (Val): 0.1208
# Epoch [134/500], Loss(Train): 0.00047, Loss(Val): 0.00036, R² (Val): 0.1241
# Epoch [135/500], Loss(Train): 0.00049, Loss(Val): 0.00037, R² (Val): 0.1221
# Epoch [136/500], Loss(Train): 0.00047, Loss(Val): 0.00036, R² (Val): 0.1254
# Epoch [137/500], Loss(Train): 0.00047, Loss(Val): 0.00037, R² (Val): 0.1118
# Epoch [138/500], Loss(Train): 0.00047, Loss(Val): 0.00037, R² (Val): 0.1047
# Epoch [139/500], Loss(Train): 0.00046, Loss(Val): 0.00037, R² (Val): 0.1085
# Epoch [140/500], Loss(Train): 0.00047, Loss(Val): 0.00037, R² (Val): 0.1110
# Epoch [141/500], Loss(Train): 0.00047, Loss(Val): 0.00036, R² (Val): 0.1236
# Epoch [142/500], Loss(Train): 0.00045, Loss(Val): 0.00037, R² (Val): 0.1206
# Epoch [143/500], Loss(Train): 0.00047, Loss(Val): 0.00037, R² (Val): 0.1224
# Epoch [144/500], Loss(Train): 0.00046, Loss(Val): 0.00037, R² (Val): 0.1075
# Epoch [145/500], Loss(Train): 0.00046, Loss(Val): 0.00037, R² (Val): 0.1186
# Epoch [146/500], Loss(Train): 0.00047, Loss(Val): 0.00037, R² (Val): 0.1201
# Epoch [147/500], Loss(Train): 0.00047, Loss(Val): 0.00036, R² (Val): 0.1280
#    -> Mejorado. Guardando modelo...
# Epoch [148/500], Loss(Train): 0.00048, Loss(Val): 0.00037, R² (Val): 0.1209
# Epoch [149/500], Loss(Train): 0.00045, Loss(Val): 0.00036, R² (Val): 0.1239
# Epoch [150/500], Loss(Train): 0.00046, Loss(Val): 0.00038, R² (Val): 0.0982
# Epoch [151/500], Loss(Train): 0.00047, Loss(Val): 0.00037, R² (Val): 0.1007
# Epoch [152/500], Loss(Train): 0.00046, Loss(Val): 0.00037, R² (Val): 0.1141
# Epoch [153/500], Loss(Train): 0.00046, Loss(Val): 0.00036, R² (Val): 0.1284
#    -> Mejorado. Guardando modelo...
# Epoch [154/500], Loss(Train): 0.00049, Loss(Val): 0.00037, R² (Val): 0.1121
# Epoch [155/500], Loss(Train): 0.00047, Loss(Val): 0.00037, R² (Val): 0.1185
# Epoch [156/500], Loss(Train): 0.00045, Loss(Val): 0.00036, R² (Val): 0.1286
#    -> Mejorado. Guardando modelo...
# Epoch [157/500], Loss(Train): 0.00047, Loss(Val): 0.00036, R² (Val): 0.1280
# Epoch [158/500], Loss(Train): 0.00046, Loss(Val): 0.00036, R² (Val): 0.1262
# Epoch [159/500], Loss(Train): 0.00045, Loss(Val): 0.00037, R² (Val): 0.1195
# Epoch [160/500], Loss(Train): 0.00046, Loss(Val): 0.00037, R² (Val): 0.1159
# Epoch [161/500], Loss(Train): 0.00048, Loss(Val): 0.00036, R² (Val): 0.1301
#    -> Mejorado. Guardando modelo...
# Epoch [162/500], Loss(Train): 0.00046, Loss(Val): 0.00037, R² (Val): 0.1212
# Epoch [163/500], Loss(Train): 0.00045, Loss(Val): 0.00037, R² (Val): 0.1197
# Epoch [164/500], Loss(Train): 0.00047, Loss(Val): 0.00037, R² (Val): 0.1190
# Epoch [165/500], Loss(Train): 0.00046, Loss(Val): 0.00037, R² (Val): 0.1104
# Epoch [166/500], Loss(Train): 0.00045, Loss(Val): 0.00037, R² (Val): 0.1011
# Epoch [167/500], Loss(Train): 0.00046, Loss(Val): 0.00036, R² (Val): 0.1231
# Epoch [168/500], Loss(Train): 0.00047, Loss(Val): 0.00036, R² (Val): 0.1235
# Epoch [169/500], Loss(Train): 0.00046, Loss(Val): 0.00036, R² (Val): 0.1259
# Epoch [170/500], Loss(Train): 0.00045, Loss(Val): 0.00037, R² (Val): 0.1162
# Epoch [171/500], Loss(Train): 0.00046, Loss(Val): 0.00037, R² (Val): 0.0993
# Epoch [172/500], Loss(Train): 0.00045, Loss(Val): 0.00037, R² (Val): 0.1176
# Epoch [173/500], Loss(Train): 0.00047, Loss(Val): 0.00037, R² (Val): 0.1170
# Epoch [174/500], Loss(Train): 0.00045, Loss(Val): 0.00036, R² (Val): 0.1271
# Epoch [175/500], Loss(Train): 0.00046, Loss(Val): 0.00036, R² (Val): 0.1230
# Epoch [176/500], Loss(Train): 0.00046, Loss(Val): 0.00036, R² (Val): 0.1253
# Epoch [177/500], Loss(Train): 0.00046, Loss(Val): 0.00036, R² (Val): 0.1246
# Epoch [178/500], Loss(Train): 0.00046, Loss(Val): 0.00036, R² (Val): 0.1273
# Epoch [179/500], Loss(Train): 0.00045, Loss(Val): 0.00037, R² (Val): 0.1034
# Epoch [180/500], Loss(Train): 0.00046, Loss(Val): 0.00037, R² (Val): 0.1156
# Epoch [181/500], Loss(Train): 0.00045, Loss(Val): 0.00036, R² (Val): 0.1267
#
# ¡Early Stopping activado en la época 181!
# La pérdida de validación no mejoró por 20 épocas.
# Cargando pesos del mejor modelo guardado.
# Entrenamiento completado.

# %%
plt.figure(figsize=(15, 6))

#(MSE)
plt.subplot(1, 2, 1) 
plt.plot(history_loss, label='Pérdida (Loss) - Entrenamiento')
plt.plot(history_val_loss, label='Pérdida (Loss) - Validación')
plt.title('Curva de Pérdida (MSE) vs. Épocas')
plt.ylabel('Pérdida (MSE)')
plt.xlabel('Épocas')
plt.legend(loc='upper right')
plt.grid(True)

# Curva de Performance
plt.subplot(1, 2, 2) 
plt.plot(history_r2_score, label='R² (Performance) - Validación', color='green')
plt.title('Curva de Performance (R²) vs. Épocas')
plt.ylabel('Score R² (Coef. de Determinación)')
plt.xlabel('Épocas')
plt.legend(loc='lower right')
plt.grid(True)

plt.tight_layout() 
plt.show()

# %% [markdown]
# ### VERIFICACION DE MEJORES MODELOS

# %% [markdown]
# Prueba 1 (157 epocas, la mejor 127)

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import torch

print("\n--- Iniciando Evaluación Final del Mejor Modelo ---")
model.eval() 

all_y_test = []
all_outputs_test = []

with torch.no_grad(): 
    for batch_X_test, batch_Y_test in test_loader:
        outputs_test = model(batch_X_test)
        
        
        all_y_test.append(batch_Y_test.cpu())
        all_outputs_test.append(outputs_test.cpu())

all_y_test = torch.cat(all_y_test).numpy()
all_outputs_test = torch.cat(all_outputs_test).numpy()

y_test_real = scaler_y.inverse_transform(all_y_test)
y_pred_real = scaler_y.inverse_transform(all_outputs_test)

test_mse = mean_squared_error(y_test_real, y_pred_real)
test_rmse = np.sqrt(test_mse) 
test_mae = mean_absolute_error(y_test_real, y_pred_real)
test_r2 = r2_score(y_test_real, y_pred_real)

print("\n--- Métricas Finales del Modelo (Época 137) ---")
print(f"  Score R² (Test):     {test_r2:.4f}")
print(f"  Error (MAE Test):    {test_mae:.4f} (Unidades de Demanda)")
print(f"  Error (RMSE Test):   {test_rmse:.4f} (Unidades de Demanda)")
print("\nEl MAE significa que, en promedio, las predicciones del modelo")
print(f"se desvían en {test_mae:.2f} unidades de la demanda real.")

plt.figure(figsize=(12, 6))
plt.plot(y_test_real, label='Demanda Real (Test)', color='blue', alpha=0.7)
plt.plot(y_pred_real, label='Predicción del Modelo', color='orange', linestyle='--')
plt.title('Comparación: Demanda Real vs. Predicción del Modelo')
plt.ylabel('Demanda Quincenal (Unidades Reales)')
plt.xlabel('Muestras de Prueba (Ordenadas)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# --- Iniciando Evaluación Final del Mejor Modelo ---
#
# --- Métricas Finales del Modelo (Época 137) ---
#   Score R² (Test):     0.2190
#   Error (MAE Test):    2.6828 (Unidades de Demanda)
#   Error (RMSE Test):   3.6120 (Unidades de Demanda)
#
# El MAE significa que, en promedio, las predicciones del modelo
# se desvían en 2.68 unidades de la demanda real.

# %% [markdown]
# Prueba 2 (181 epocas, mejor 161)

# %%
print("\n--- Iniciando Evaluación Final del Mejor Modelo ---")
model.eval() 

all_y_test = []
all_outputs_test = []

with torch.no_grad(): 
    for batch_X_test, batch_Y_test in test_loader:
        outputs_test = model(batch_X_test)
        
        all_y_test.append(batch_Y_test.cpu())
        all_outputs_test.append(outputs_test.cpu())


all_y_test = torch.cat(all_y_test).numpy()
all_outputs_test = torch.cat(all_outputs_test).numpy()

y_test_real = scaler_y.inverse_transform(all_y_test)
y_pred_real = scaler_y.inverse_transform(all_outputs_test)

test_mse = mean_squared_error(y_test_real, y_pred_real)
test_rmse = np.sqrt(test_mse) 
test_mae = mean_absolute_error(y_test_real, y_pred_real)
test_r2 = r2_score(y_test_real, y_pred_real)

print("\n--- Métricas Finales del Modelo (Época 137) ---")
print(f"  Score R² (Test):     {test_r2:.4f}")
print(f"  Error (MAE Test):    {test_mae:.4f} (Unidades de Demanda)")
print(f"  Error (RMSE Test):   {test_rmse:.4f} (Unidades de Demanda)")
print("\nEl MAE significa que, en promedio, las predicciones del modelo")
print(f"se desvían en {test_mae:.2f} unidades de la demanda real.")

plt.figure(figsize=(12, 6))
plt.plot(y_test_real, label='Demanda Real (Test)', color='blue', alpha=0.7)
plt.plot(y_pred_real, label='Predicción del Modelo', color='orange', linestyle='--')
plt.title('Comparación: Demanda Real vs. Predicción del Modelo')
plt.ylabel('Demanda Quincenal (Unidades Reales)')
plt.xlabel('Muestras de Prueba (Ordenadas)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# --- Iniciando Evaluación Final del Mejor Modelo ---
#
# --- Métricas Finales del Modelo (Época 137) ---
#   Score R² (Test):     0.2202
#   Error (MAE Test):    2.7379 (Unidades de Demanda)
#   Error (RMSE Test):   3.6093 (Unidades de Demanda)
#
# El MAE significa que, en promedio, las predicciones del modelo
# se desvían en 2.74 unidades de la demanda real.
